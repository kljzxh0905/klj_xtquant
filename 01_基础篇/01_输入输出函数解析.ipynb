# %%
print('从python入门到精通')
# Out:
# 从python入门到精通

# %%
# 1.1.1 什么是Python
# Python是一种解释型、面向对象、动态数据类型的高级程序设计语言
# Python是一种解释型语言，这意味着开发人员无需担心内存管理、内存分配等问题，这些问题都由Python解释器来处理
# Python是一种面向对象的语言，这意味着Python支持面向对象的编程风格或面向对象的编程范式
# Python是一种动态数据类型的语言，这意味着在Python中，变量的数据类型是根据变量存储的值来推断的，而不是由开发人员在定义变量时指定的
# Python是一种高级程序设计语言，这意味着Python代码更接近自然语言，更容易阅读和理解

# 1.1.2 Python的特点
# 1. 简单易学
# 2. 免费开源
# 3. 高层语言
# 4. 可移植性
# 5. 解释性
# 6. 面向对象
# 7. 可扩展性
# 8. 可嵌入性
# 9. 丰富的库
# 10. 规范的代码

# 1.1.3 Python的应用领域
# 1. 网络编程
# 2. Web开发
# 3. 数据分析
# 4. 人工智能
# 5. 机器学习
# 6. 深度学习
# 7. 自然语言处理
# 8. 数据挖掘
# 9. 云计算
# 10. 科学计算
# 11. 图像处理
# 12. 游戏开发
# 13. 办公自动化
# 14. 系统管理
# 15. 自动化测试
# 16. 金融
# 17. 医学
# 18. 农业
# 19. 物联网
# 20. 区块链

# 1.1.4 Python的版本
# Python 2.x和Python 3.x是两个不兼容的版本，其中Python 2.x是Python 3.x的前身，Python 3.x是Python 2.x的升级版本
# Python 2.x和Python 3.x的主要区别有：
# 1. print函数
# 2. 整数除法
# 3. Unicode字符串
# 4. xrange函数
# 5. input函数
# 6. exec函数
# 7. 异常
# 8. 模块

# 1.1.5 Python的安装
# Python官网：https://www.python.org/
# Python的安装包：https://www.python.org/downloads/
# Python的安装步骤：
# 1. 下载Python安装包
# 2. 运行Python安装包
# 3. 安装Python
# 4. 配置环境变量
# 5. 验证Python安装

# 1.1.6 Python的运行
# Python的运行方式有两种：
# 1. 交互式运行
# 2. 脚本式运行
# 交互式运行：在命令行中输入python命令，然后在Python提示符>>>后输入Python代码，按回车键执行Python代码
# 脚本式运行：在命令行中输入python命令，然后在命令行中输入Python代码，按回车键执行Python代码

# 1.1.7 Python的开发工具
# Python的开发工具有很多，常用的Python开发工具有：
# 1. IDLE
# 2. PyCharm
# 3. Eclipse
# 4. Visual Studio Code
# 5. Sublime Text
# 6. Atom
# 7. Jupyter Notebook

# 1.1.8 Python的第一个程序
# Python的第一个程序是输出Hello World！
# Python的第一个程序代码如下：
print('Hello World!')
# Python的第一个程序代码解释：
# print是Python的内置函数，用于输出指定的字符串
# Hello World!是要输出的字符串
# 单引号或双引号用于表示字符串的开始和结束

# 1.1.9 Python的注释
# Python的注释用于解释代码，提高代码的可读性
# Python的注释有两种：
# 1. 单行注释
# 2. 多行注释
# Python的单行注释以#开始，直到行末结束
# Python的多行注释以三个单引号或三个双引号开始和结束
# Python的注释代码如下：
# 这是Python的单行注释
'''
# 这是Python的多行注释
'''
# 这是Python的多行注释
'''
'''

# 1.1.10 Python的缩进
# Python的缩进用于表示代码块，提高代码的可读性
# Python的缩进有两种：
# 1. 用空格缩进
# 2. 用制表符缩进
# Python的缩进要求相同代码块的缩进量相同
# Python的缩进代码如下：
if True:
    print('True')
else:
    print('False')

# 1.1.11 Python的行尾
# Python的行尾用于表示一行代码的结束
# Python的行尾有两种：
# 1. 分号
# 2. 换行
# Python的行尾代码如下：
print('Hello World!'); print('Hello Python!')
print('Hello World!')
print('Hello Python!')

# 1.1.12 Python的大小写
# Python的大小写是敏感的，即Python区分大小写
# Python的大小写代码如下：
print('Hello World!')
# Print('Hello World!') # 这里的P是大写，不是内置函数，会报错
# PRINT('Hello World!') # 这里的PRINT是大写，不是内置函数，会报错

# 1.1.13 Python的空行
# Python的空行用于分隔代码，提高代码的可读性
# Python的空行代码如下：
print('Hello World!')
print('Hello Python!')
# 这是Python的空行
print('Hello World!')
print('Hello Python!')

# 1.1.14 Python的多行语句
# Python的多行语句用于表示一条语句分多行书写
# Python的多行语句有两种：
# 1. 反斜杠
# 2. 圆括号
# Python的多行语句代码如下：
print('Hello World! \
Hello Python!')
print('Hello World! '
      'Hello Python!')

# 1.1.15 Python的引号
# Python的引号用于表示字符串的开始和结束
# Python的引号有三种：
# 1. 单引号
# 2. 双引号
# 3. 三引号
# Python的引号代码如下：
print('Hello World!')
print("Hello World!")
print('''Hello World!''')

# 1.1.16 Python的转义字符
# Python的转义字符用于表示特殊字符
# Python的转义字符有很多，常用的转义字符有：
# 1. \n：换行
# 2. \t：制表符
# 3. \r：回车
# 4. \b：退格
# 5. \f：换页
# 6. \\：反斜杠
# 7. \'：单引号
# 8. \"：双引号
# 9. \0：空字符
# Python的转义字符代码如下：
print('Hello\nWorld!')
print('Hello\tWorld!')
print('Hello\rWorld!')
print('Hello\bWorld!')
print('Hello\fWorld!')
print('Hello\\World!')
print('Hello\'World!')
print('Hello\"World!')
print('Hello\0World!')

# 1.1.17 Python的格式化字符串
# Python的格式化字符串用于格式化输出字符串
# Python的格式化字符串有两种：
# 1. %格式化字符串
# 2. format方法
# Python的格式化字符串代码如下：
name = 'Python'
age = 30
print('Hello, %s!' % name)
print('Hello, %s! You are %d years old.' % (name, age))
print('Hello, {}! You are {} years old.'.format(name, age))
print(f'Hello, {name}! You are {age} years old.')
# Out:
# Hello World!
# True
# Hello World!
# Hello Python!
# Hello World!
# Hello Python!
# Hello World!
# Hello World!
# Hello Python!
# Hello World!
# Hello Python!
# Hello World! Hello Python!
# Hello World! Hello Python!
# Hello World!
# Hello World!
# Hello World!
# Hello
# World!
# Hello	World!
# World!
# HellWorld!
# HelloWorld!
# Hello\World!
# Hello'World!
# Hello"World!
# HelloWorld!
# Hello, Python!
# Hello, Python! You are 30 years old.
# Hello, Python! You are 30 years old.
# Hello, Python! You are 30 years old.
