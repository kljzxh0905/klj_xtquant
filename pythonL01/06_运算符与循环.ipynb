# %%
# 运算符
# 算术运算符
# + - * / % ** //
# 比较运算符
# == != > < >= <=
# 逻辑运算符
# and or not
# 赋值运算符
# = += -= *= /= %= **= //= &= |= ^= >>= <<=
# 运算符优先级
# ** > ~ + - > * / % // > + -

# %%
# 算术运算符
a = 21
b = 10
c = 0
c = a + b
print("a + b = ", c)
c = a - b
print("a - b = ", c)
c = a * b
print("a * b = ", c)
c = a / b
print("a / b = ", c)
c = a % b
print("a % b = ", c)
a = 2
b = 3
c = a ** b
print("a ** b = ", c)
a = 10
b = 5
c = a // b
print("a // b = ", c)
print('*' * 50)
# Out:
# a + b =  31
# a - b =  11
# a * b =  210
# a / b =  2.1
# a % b =  1
# a ** b =  8
# a // b =  2
# **************************************************

# %%
# 比较运算符
a = 21
b = 10
if a == b:
    print("a 等于 b")
else:
    print("a 不等于 b")
if a != b:
    print("a 不等于 b")
else:
    print("a 等于 b")
if a < b:
    print("a 小于 b")
else:
    print("a 大于 b")
if a > b:
    print("a 大于 b")
else:
    print("a 小于 b")
a = 5
b = 20
if a <= b:
    print("a 小于等于 b")
else:
    print("a 大于 b")
if b >= a:
    print("b 大于等于 a")
else:
    print("b 小于 a")
print('*' * 50)
# Out:
# a 不等于 b
# a 不等于 b
# a 大于 b
# a 大于 b
# a 小于等于 b
# b 大于等于 a
# **************************************************

# %%
# 逻辑运算符
a = 10
b = 20
if a and b:
    print("变量 a 和 b 都为 true")
else:
    print("变量 a 和 b 有一个不为 true")
if a or b:
    print("变量 a 和 b 至少有一个为 true")
else:
    print("变量 a 和 b 都不为 true")
a = 0
if a and b:
    print("变量 a 和 b 都为 true")
else:
    print("变量 a 和 b 有一个不为 true")
if a or b:
    print("变量 a 和 b 至少有一个为 true")
else:
    print("变量 a 和 b 都不为 true")
if not (a and b):
    print("变量 a 和 b 至少有一个不为 true")
else:
    print("变量 a 和 b 都为 true")
print('*' * 50)
# Out:
# 变量 a 和 b 都为 true
# 变量 a 和 b 至少有一个为 true
# 变量 a 和 b 有一个不为 true
# 变量 a 和 b 至少有一个为 true
# 变量 a 和 b 至少有一个不为 true
# **************************************************

# %%
# 赋值运算符
a = 21
b = 10
c = 0
c = a + b
print("c = a + b = ", c)
c += a # c = c + a
print("c += a = ", c)
c *= a # c = c * a
print("c *= a = ", c)
c /= a # c = c / a
print("c /= a = ", c)
c = 2
c %= a # c = c % a
print("c %= a = ", c)
c **= a # c = c ** a
print("c **= a = ", c)
c //= a # c = c // a
print("c //= a = ", c)
print('*' * 50)
# Out:
# c = a + b =  31
# c += a =  52
# c *= a =  1092
# c /= a =  52.0
# c %= a =  2
# c **= a =  2097152
# c //= a =  99864
# **************************************************

# %%
# python中有c++中的++和--运算符吗？
# python中没有++和--运算符，只有+=和-=运算符

# %%
# while循环
count = 0
while count < 9:
    print("The count is: ", count)
    count += 1
# Out:
# The count is:  0
# The count is:  1
# The count is:  2
# The count is:  3
# The count is:  4
# The count is:  5
# The count is:  6
# The count is:  7
# The count is:  8

# %%
# 用while循环打印5遍"hello world"
i = 0
while i < 5:
    print("hello world")
    i += 1

print("循环结束后的i值为：", i)
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# 循环结束后的i值为： 5

# %%
# while死循环
var = 1   # 表达式永远为true
i = 0
while var == 1:
    print("这是无限循环")
    i += 1
    print(f"i = {i}")
    if i == 20000:
        break
# Out:
# 这是无限循环
# i = 1
# 这是无限循环
# i = 2
# 这是无限循环
# i = 3
# 这是无限循环
# i = 4
# 这是无限循环
# i = 5
# 这是无限循环
# i = 6
# 这是无限循环
# i = 7
# 这是无限循环
# i = 8
# 这是无限循环
# i = 9
# 这是无限循环
# i = 10
# 这是无限循环
# i = 11
# 这是无限循环
# i = 12
# 这是无限循环
# i = 13
# 这是无限循环
# i = 14
# 这是无限循环
# i = 15
# 这是无限循环
# i = 16
# 这是无限循环
# i = 17
# 这是无限循环
# i = 18
# 这是无限循环
# i = 19
# 这是无限循环
# i = 20
# 这是无限循环
# i = 21
# 这是无限循环
# i = 22
# 这是无限循环
# i = 23
# 这是无限循环
# i = 24
# 这是无限循环
# i = 25
# 这是无限循环
# i = 26
# 这是无限循环
# i = 27
# 这是无限循环
# i = 28
# 这是无限循环
# i = 29
# 这是无限循环
# i = 30
# 这是无限循环
# i = 31
# 这是无限循环
# i = 32
# 这是无限循环
# i = 33
# 这是无限循环
# i = 34
# 这是无限循环
# i = 35
# 这是无限循环
# i = 36
# 这是无限循环
# i = 37
# 这是无限循环
# i = 38
# 这是无限循环
# i = 39
# 这是无限循环
# i = 40
# 这是无限循环
# i = 41
# 这是无限循环
# i = 42
# 这是无限循环
# i = 43
# 这是无限循环
# i = 44
# 这是无限循环
# i = 45
# 这是无限循环
# i = 46
# 这是无限循环
# i = 47
# 这是无限循环
# i = 48
# 这是无限循环
# i = 49
# 这是无限循环
# i = 50
# 这是无限循环
# i = 51
# 这是无限循环
# i = 52
# 这是无限循环
# i = 53
# 这是无限循环
# i = 54
# 这是无限循环
# i = 55
# 这是无限循环
# i = 56
# ...

# %%
# 用while循环实现1-100求和
result = 0
i = 0
while i <= 100:
    result += i
    i += 1
print(f"1-100的和为：{result}")
# Out:
# 1-100的和为：5050

# %%
# 用while循环实现0-100偶数求和
result = 0
i = 0
while i <= 100:
    result += i
    i += 2
print(f"0-100的偶数和为：{result}")
# Out:
# 0-100的偶数和为：2550

# %%
# break和continue break是结束整个循环，continue是结束本次循环
i = 0
while i < 10:
    if i == 3:
        break
    print(i)
    i += 1
# Out:
# 0
# 1
# 2

# %%
i = 0
while i < 10:
    i += 1
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
# 用while循环打印直角三角形，符号为"*"
i = 1
while i <= 5:
    print("*" * i)
    i += 1

# 用while循环打印等腰三角形，符号为"*"
i = 1
while i <= 5:
    print(" " * (5 - i) + "*" * (2 * i - 1))
    i += 1
# Out:
# *
# **
# ***
# ****
# *****
#     *
#    ***
#   *****
#  *******
# *********

# %%
'''
九九乘法表
1 * 1 = 1
1 * 2 = 2 2 * 2 = 4
1 * 3 = 3 2 * 3 = 6 3 * 3 = 9
1 * 4 = 4 2 * 4 = 8 3 * 4 = 12 4 * 4 = 16
1 * 5 = 5 2 * 5 = 10 3 * 5 = 15 4 * 5 = 20 5 * 5 = 25
1 * 6 = 6 2 * 6 = 12 3 * 6 = 18 4 * 6 = 24 5 * 6 = 30 6 * 6 = 36
1 * 7 = 7 2 * 7 = 14 3 * 7 = 21 4 * 7 = 28 5 * 7 = 35 6 * 7 = 42 7 * 7 = 49
1 * 8 = 8 2 * 8 = 16 3 * 8 = 24 4 * 8 = 32 5 * 8 = 40 6 * 8 = 48 7 * 8 = 56 8 * 8 = 64
1 * 9 = 9 2 * 9 = 18 3 * 9 = 27 4 * 9 = 36 5 * 9 = 45 6 * 9 = 54 7 * 9 = 63 8 * 9 = 72 9 * 9 = 81
'''
# Out:
# '\n九九乘法表\n1 * 1 = 1\n1 * 2 = 2 2 * 2 = 4\n1 * 3 = 3 2 * 3 = 6 3 * 3 = 9\n1 * 4 = 4 2 * 4 = 8 3 * 4 = 12 4 * 4 = 16\n1 * 5 = 5 2 * 5 = 10 3 * 5 = 15 4 * 5 = 20 5 * 5 = 25\n1 * 6 = 6 2 * 6 = 12 3 * 6 = 18 4 * 6 = 24 5 * 6 = 30 6 * 6 = 36\n1 * 7 = 7 2 * 7 = 14 3 * 7 = 21 4 * 7 = 28 5 * 7 = 35 6 * 7 = 42 7 * 7 = 49\n1 * 8 = 8 2 * 8 = 16 3 * 8 = 24 4 * 8 = 32 5 * 8 = 40 6 * 8 = 48 7 * 8 = 56 8 * 8 = 64\n1 * 9 = 9 2 * 9 = 18 3 * 9 = 27 4 * 9 = 36 5 * 9 = 45 6 * 9 = 54 7 * 9 = 63 8 * 9 = 72 9 * 9 = 81\n'

# %%
# 定义一个变量，用于控制行数
row = 1
while row <= 9:
    # 定义一个变量，用于控制列数
    col = 1
    while col <= row:
        print(f"{col} * {row} = {col * row}", end="\t")
        col += 1
    print()
    row += 1
# Out:
# 1 * 1 = 1
# 1 * 2 = 2	2 * 2 = 4
# 1 * 3 = 3	2 * 3 = 6	3 * 3 = 9
# 1 * 4 = 4	2 * 4 = 8	3 * 4 = 12	4 * 4 = 16
# 1 * 5 = 5	2 * 5 = 10	3 * 5 = 15	4 * 5 = 20	5 * 5 = 25
# 1 * 6 = 6	2 * 6 = 12	3 * 6 = 18	4 * 6 = 24	5 * 6 = 30	6 * 6 = 36
# 1 * 7 = 7	2 * 7 = 14	3 * 7 = 21	4 * 7 = 28	5 * 7 = 35	6 * 7 = 42	7 * 7 = 49
# 1 * 8 = 8	2 * 8 = 16	3 * 8 = 24	4 * 8 = 32	5 * 8 = 40	6 * 8 = 48	7 * 8 = 56	8 * 8 = 64
# 1 * 9 = 9	2 * 9 = 18	3 * 9 = 27	4 * 9 = 36	5 * 9 = 45	6 * 9 = 54	7 * 9 = 63	8 * 9 = 72	9 * 9 = 81

# %%
# 定义一个变量，用于控制行数
row = 1
while row <= 9:
    # 只打印行数
    print(f"{row}")
    # print()
    row += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# 打印九九乘法表的第九行
# 定义一个变量，用于控制行数
row = 1
while row <= 9:
    # 定义一个变量，用于控制列数    
    if row == 9:
        col = 1
        while col <= row:
            print(f"{col} * {row} = {col * row}", end="\t")
            col += 1
    row += 1
# Out:
# 1 * 9 = 9	2 * 9 = 18	3 * 9 = 27	4 * 9 = 36	5 * 9 = 45	6 * 9 = 54	7 * 9 = 63	8 * 9 = 72	9 * 9 = 81
